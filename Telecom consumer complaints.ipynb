# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv("Comcast_telecom_complaints_data.csv")

# %%
df.head()
# Out:
#   Ticket #                                 Customer Complaint      Date  \
# 0   250635                      Comcast Cable Internet Speeds  22-04-15
# 1   223441       Payment disappear - service got disconnected  04-08-15
# 2   242732                                  Speed and Service  18-04-15
# 3   277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4   307175         Comcast not working and no service to boot  26-05-15
#
#   Date_month_year         Time        Received Via      City     State  \
# 0       22-Apr-15   3:53:50 PM  Customer Care Call  Abingdon  Maryland
# 1       04-Aug-15  10:22:56 AM            Internet   Acworth   Georgia
# 2       18-Apr-15   9:55:47 AM            Internet   Acworth   Georgia
# 3       05-Jul-15  11:59:35 AM            Internet   Acworth   Georgia
# 4       26-May-15   1:25:26 PM            Internet   Acworth   Georgia
#
#    Zip code  Status Filing on Behalf of Someone
# 0     21009  Closed                          No
# ...

# %%
df.isnull().sum()
# Out:
# Ticket #                       0
# Customer Complaint             0
# Date                           0
# Date_month_year                0
# Time                           0
# Received Via                   0
# City                           0
# State                          0
# Zip code                       0
# Status                         0
# Filing on Behalf of Someone    0
# dtype: int64

# %%
df.describe()
# Out:
#            Zip code
# count   2224.000000
# mean   47994.393435
# std    28885.279427
# min     1075.000000
# 25%    30056.500000
# 50%    37211.000000
# 75%    77058.750000
# max    99223.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224 entries, 0 to 2223
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Ticket #                     2224 non-null   object
#  1   Customer Complaint           2224 non-null   object
#  2   Date                         2224 non-null   object
#  3   Date_month_year              2224 non-null   object
#  4   Time                         2224 non-null   object
#  5   Received Via                 2224 non-null   object
#  6   City                         2224 non-null   object
#  7   State                        2224 non-null   object
#  8   Zip code                     2224 non-null   int64
#  9   Status                       2224 non-null   object
#  10  Filing on Behalf of Someone  2224 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 191.2+ KB

# %%
df['Date_month_year']=df['Date_month_year'].apply(pd.to_datetime)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224 entries, 0 to 2223
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Ticket #                     2224 non-null   object
#  1   Customer Complaint           2224 non-null   object
#  2   Date                         2224 non-null   object
#  3   Date_month_year              2224 non-null   datetime64[ns]
#  4   Time                         2224 non-null   object
#  5   Received Via                 2224 non-null   object
#  6   City                         2224 non-null   object
#  7   State                        2224 non-null   object
#  8   Zip code                     2224 non-null   int64
#  9   Status                       2224 non-null   object
#  10  Filing on Behalf of Someone  2224 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 191.2+ KB

# %%
df=df.set_index('Date_month_year')

# %%
df.head()
# Out:
#                 Ticket #                                 Customer Complaint  \
# Date_month_year
# 2015-04-22        250635                      Comcast Cable Internet Speeds
# 2015-08-04        223441       Payment disappear - service got disconnected
# 2015-04-18        242732                                  Speed and Service
# 2015-07-05        277946  Comcast Imposed a New Usage Cap of 300GB that ...
# 2015-05-26        307175         Comcast not working and no service to boot
#
#                      Date         Time        Received Via      City  \
# Date_month_year
# 2015-04-22       22-04-15   3:53:50 PM  Customer Care Call  Abingdon
# 2015-08-04       04-08-15  10:22:56 AM            Internet   Acworth
# 2015-04-18       18-04-15   9:55:47 AM            Internet   Acworth
# 2015-07-05       05-07-15  11:59:35 AM            Internet   Acworth
# 2015-05-26       26-05-15   1:25:26 PM            Internet   Acworth
#
# ...

# %%
months=df.groupby(pd.Grouper(freq='M')).size().plot()
plt.xlabel('Months')
plt.ylabel('Frequency')
plt.title('Monthly Frequency Complaints')
# Out:
# Text(0.5, 1.0, 'Monthly Frequency Complaints')

# %%
Days=df.groupby(pd.Grouper(freq='D')).size().plot()
plt.xlabel('Days')
plt.ylabel('Frequency')
plt.title('Daily Frequency Complaints')
plt.show(5)

# %%
df['Date'].head()
# Out:
# Date_month_year
# 2015-04-22    22-04-15
# 2015-08-04    04-08-15
# 2015-04-18    18-04-15
# 2015-07-05    05-07-15
# 2015-05-26    26-05-15
# Name: Date, dtype: object

# %%
df=df.sort_values('Date')

# %%
df.head()
# Out:
#                 Ticket #                                Customer Complaint  \
# Date_month_year
# 2015-01-04        211976  Fraudulent claims reported to collections agency
# 2015-01-04        211677                        Comcast refusal of service
# 2015-01-04        212507                                     Comcast Cable
# 2015-01-04        213120                                     Data Overages
# 2015-01-04        211478                                           Comcast
#
#                      Date         Time        Received Via              City  \
# Date_month_year
# 2015-01-04       04-01-15   1:26:53 PM  Customer Care Call           Atlanta
# 2015-01-04       04-01-15  12:01:06 PM  Customer Care Call             Wayne
# 2015-01-04       04-01-15   3:54:43 PM            Internet          Franklin
# 2015-01-04       04-01-15   8:05:57 PM            Internet          Savannah
# 2015-01-04       04-01-15  10:47:35 AM            Internet  North Huntingdon
#
# ...

# %%
df['Date'].value_counts().plot()
plt.xlabel("Days")
plt.ylabel("Frequency")
plt.title("Complaints Per Day")
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# Text(0.5, 1.0, 'Complaints Per Day')

# %%
df[:10]
# Out:
#                 Ticket #                                 Customer Complaint  \
# Date_month_year
# 2015-01-04        211976   Fraudulent claims reported to collections agency
# 2015-01-04        211677                         Comcast refusal of service
# 2015-01-04        212507                                      Comcast Cable
# 2015-01-04        213120                                      Data Overages
# 2015-01-04        211478                                            Comcast
# 2015-01-04        211255                                 Comcast harassment
# 2015-01-04        213355  Comcast is ignoring me now. They are making NO...
# 2015-01-04        211904  Unable to get in touch with anyone that has th...
# 2015-01-04        212228        Comcast Lied About Pricing And Installation
# 2015-01-04        212595                                        overcharged
#
#                      Date         Time        Received Via              City  \
# Date_month_year
# ...

# %%
df.shape
# Out:
# (2224, 10)

# %%
df['Customer Complaint'].unique()
# Out:
# array(['Fraudulent claims reported to collections agency',
#        'Comcast refusal of service', 'Comcast Cable', ...,
#        'Comcast of East Windsor NJ Complaint',
#        'Complaint against Comcast for incredibly bad service',
#        'Questionable internet slowdown'], dtype=object)

# %%
df['Customer Complaint'].value_counts()[:13].plot.bar()
# Out:
# <AxesSubplot:>

# %%
internet_issues1=df[df['Customer Complaint'].str.contains('internet')].count()

# %%
internet_issues1
# Out:
# Ticket #                       195
# Customer Complaint             195
# Date                           195
# Time                           195
# Received Via                   195
# City                           195
# State                          195
# Zip code                       195
# Status                         195
# Filing on Behalf of Someone    195
# dtype: int64

# %%
internet_issues2=df[df['Customer Complaint'].str.contains('speed')].count()

# %%
internet_issues2
# Out:
# Ticket #                       114
# Customer Complaint             114
# Date                           114
# Time                           114
# Received Via                   114
# City                           114
# State                          114
# Zip code                       114
# Status                         114
# Filing on Behalf of Someone    114
# dtype: int64

# %%
billing1=df[df['Customer Complaint'].str.contains('billing')].count()

# %%
billing1
# Out:
# Ticket #                       126
# Customer Complaint             126
# Date                           126
# Time                           126
# Received Via                   126
# City                           126
# State                          126
# Zip code                       126
# Status                         126
# Filing on Behalf of Someone    126
# dtype: int64

# %%
billing2=df[df['Customer Complaint'].str.contains('charge')].count()

# %%
billing2
# Out:
# Ticket #                       85
# Customer Complaint             85
# Date                           85
# Time                           85
# Received Via                   85
# City                           85
# State                          85
# Zip code                       85
# Status                         85
# Filing on Behalf of Someone    85
# dtype: int64

# %%
internet_issues3=df[df['Customer Complaint'].str.contains('data')].count()

# %%
internet_issues3
# Out:
# Ticket #                       64
# Customer Complaint             64
# Date                           64
# Time                           64
# Received Via                   64
# City                           64
# State                          64
# Zip code                       64
# Status                         64
# Filing on Behalf of Someone    64
# dtype: int64

# %%
internet_issues4=df[df['Customer Complaint'].str.contains('network')].count()

# %%
internet_issues4
# Out:
# Ticket #                       1
# Customer Complaint             1
# Date                           1
# Time                           1
# Received Via                   1
# City                           1
# State                          1
# Zip code                       1
# Status                         1
# Filing on Behalf of Someone    1
# dtype: int64

# %%
internet_issues2
# Out:
# Ticket #                       114
# Customer Complaint             114
# Date                           114
# Time                           114
# Received Via                   114
# City                           114
# State                          114
# Zip code                       114
# Status                         114
# Filing on Behalf of Someone    114
# dtype: int64

# %%
service1=df[df['Customer Complaint'].str.contains('service')].count()

# %%
service1
# Out:
# Ticket #                       310
# Customer Complaint             310
# Date                           310
# Time                           310
# Received Via                   310
# City                           310
# State                          310
# Zip code                       310
# Status                         310
# Filing on Behalf of Someone    310
# dtype: int64

# %%
service2=df[df['Customer Complaint'].str.contains('customer')].count()

# %%
service2
# Out:
# Ticket #                       50
# Customer Complaint             50
# Date                           50
# Time                           50
# Received Via                   50
# City                           50
# State                          50
# Zip code                       50
# Status                         50
# Filing on Behalf of Someone    50
# dtype: int64

# %%
total_internet_issues=internet_issues1+internet_issues2+internet_issues3+internet_issues4

# %%
total_billing=billing1+billing2

# %%
total_service_issues=service1+service2

# %%
df.shape
# Out:
# (2224, 10)

# %%
other_issues=2224-(total_internet_issues+total_billing+total_service_issues)

# %%
other_issues
# Out:
# Ticket #                       1279
# Customer Complaint             1279
# Date                           1279
# Time                           1279
# Received Via                   1279
# City                           1279
# State                          1279
# Zip code                       1279
# Status                         1279
# Filing on Behalf of Someone    1279
# dtype: int64

# %%
df.tail(10)
# Out:
#                 Ticket #                                 Customer Complaint  \
# Date_month_year
# 2015-05-31        315608                            Comcast Service Failure
# 2015-05-31        315855                          Poor Service from Comcast
# 2015-05-31        315874                            Comcast Termination Fee
# 2015-05-31        315602  Comcast deceptive selling billing lack of serv...
# 2015-05-31        315997                    Hidden Product Installation Fee
# 2015-05-31        316088                                            Comcast
# 2015-05-31        315759               Comcast of East Windsor NJ Complaint
# 2015-05-31        316040                                        n/a (b) (6)
# 2015-05-31        315836  Complaint against Comcast for incredibly bad s...
# 2015-05-31        315865                     Questionable internet slowdown
#
#                      Date         Time        Received Via              City  \
# Date_month_year
# ...

# %%
df["NewStatus"]=["Open" if Status=="Open" or Status=="Pending" else "Closed" for Status in df["Status"] ]

# %%
df.head()
# Out:
#                 Ticket #                                Customer Complaint  \
# Date_month_year
# 2015-01-04        211976  Fraudulent claims reported to collections agency
# 2015-01-04        211677                        Comcast refusal of service
# 2015-01-04        212507                                     Comcast Cable
# 2015-01-04        213120                                     Data Overages
# 2015-01-04        211478                                           Comcast
#
#                      Date         Time        Received Via              City  \
# Date_month_year
# 2015-01-04       04-01-15   1:26:53 PM  Customer Care Call           Atlanta
# 2015-01-04       04-01-15  12:01:06 PM  Customer Care Call             Wayne
# 2015-01-04       04-01-15   3:54:43 PM            Internet          Franklin
# 2015-01-04       04-01-15   8:05:57 PM            Internet          Savannah
# 2015-01-04       04-01-15  10:47:35 AM            Internet  North Huntingdon
#
# ...

# %%
df[:10]
# Out:
#                 Ticket #                                 Customer Complaint  \
# Date_month_year
# 2015-01-04        211976   Fraudulent claims reported to collections agency
# 2015-01-04        211677                         Comcast refusal of service
# 2015-01-04        212507                                      Comcast Cable
# 2015-01-04        213120                                      Data Overages
# 2015-01-04        211478                                            Comcast
# 2015-01-04        211255                                 Comcast harassment
# 2015-01-04        213355  Comcast is ignoring me now. They are making NO...
# 2015-01-04        211904  Unable to get in touch with anyone that has th...
# 2015-01-04        212228        Comcast Lied About Pricing And Installation
# 2015-01-04        212595                                        overcharged
#
#                      Date         Time        Received Via              City  \
# Date_month_year
# ...

# %%
df.tail()
# Out:
#                 Ticket #                                 Customer Complaint  \
# Date_month_year
# 2015-05-31        316088                                            Comcast
# 2015-05-31        315759               Comcast of East Windsor NJ Complaint
# 2015-05-31        316040                                        n/a (b) (6)
# 2015-05-31        315836  Complaint against Comcast for incredibly bad s...
# 2015-05-31        315865                     Questionable internet slowdown
#
#                      Date         Time        Received Via          City  \
# Date_month_year
# 2015-05-31       31-05-15  11:02:38 PM  Customer Care Call     Beaverton
# 2015-05-31       31-05-15   3:25:33 PM            Internet  East Windsor
# 2015-05-31       31-05-15   9:25:28 PM            Internet    Loganville
# 2015-05-31       31-05-15   4:47:08 PM  Customer Care Call      Edgewood
# 2015-05-31       31-05-15   5:38:21 PM  Customer Care Call       Peabody
#
# ...

# %%
df.sample(10)
# Out:
#                 Ticket #                                 Customer Complaint  \
# Date_month_year
# 2015-06-19        352100                                            Comcast
# 2015-04-15        236299  service not disconnected as requested. overcha...
# 2015-06-28        370823        95 Palmer Road, Enfield NH Internet Pricing
# 2015-06-18        348338                                    Termination Fee
# 2015-06-23        360582                             Frequent interruptions
# 2015-06-24        363616                      COMCAST Poor Customer Service
# 2015-07-05        277544  Comcast charging me for items I do not want/as...
# 2015-04-13        232972                                     Internet Speed
# 2015-01-06        316846  Comcast is double billing me and not processin...
# 2015-06-30        375794                          Comcast False Advertising
#
#                      Date         Time        Received Via              City  \
# Date_month_year
# ...

# %%
df[df['NewStatus'].str.contains("Open")].count()
# Out:
# Ticket #                       517
# Customer Complaint             517
# Date                           517
# Time                           517
# Received Via                   517
# City                           517
# State                          517
# Zip code                       517
# Status                         517
# Filing on Behalf of Someone    517
# NewStatus                      517
# dtype: int64

# %%
State_Complain=df.groupby(['State','NewStatus']).size().unstack()

# %%
State_Complain
# Out:
# NewStatus             Closed  Open
# State
# Alabama                 17.0   9.0
# Arizona                 14.0   6.0
# Arkansas                 6.0   NaN
# California             159.0  61.0
# Colorado                58.0  22.0
# Connecticut              9.0   3.0
# Delaware                 8.0   4.0
# District Of Columbia    14.0   2.0
# District of Columbia     1.0   NaN
# Florida                201.0  39.0
# Georgia                208.0  80.0
# Illinois               135.0  29.0
# Indiana                 50.0   9.0
# Iowa                     1.0   NaN
# Kansas                   1.0   1.0
# Kentucky                 4.0   3.0
# Louisiana               12.0   1.0
# Maine                    3.0   2.0
# Maryland                63.0  15.0
# Massachusetts           50.0  11.0
# Michigan                92.0  23.0
# Minnesota               29.0   4.0
# Mississippi             23.0  16.0
# Missouri                 3.0   1.0
# Montana                  1.0   NaN
# ...

# %%
State_Complain.plot.bar(figsize=(10,7),stacked=True)
# Out:
# <AxesSubplot:xlabel='State'>

# %%
df.groupby(['State']).size().sort_values(ascending=False)
# Out:
# State
# Georgia                 288
# Florida                 240
# California              220
# Illinois                164
# Tennessee               143
# Pennsylvania            130
# Michigan                115
# Washington               98
# Colorado                 80
# Maryland                 78
# New Jersey               75
# Texas                    71
# Massachusetts            61
# Virginia                 60
# Indiana                  59
# Oregon                   49
# Mississippi              39
# Minnesota                33
# Alabama                  26
# Utah                     22
# Arizona                  20
# South Carolina           18
# District Of Columbia     16
# New Mexico               15
# Louisiana                13
# New Hampshire            12
# Connecticut              12
# Delaware                 12
# West Virginia            11
# Kentucky                  7
# New York                  6
# Arkansas                  6
# Maine                     5
# ...

# %%
unresolved_data=df.groupby(['State','NewStatus']).size().unstack().sort_values(by='Open',ascending=False)

# %%
unresolved_data
# Out:
# NewStatus             Closed  Open
# State
# Georgia                208.0  80.0
# California             159.0  61.0
# Tennessee               96.0  47.0
# Florida                201.0  39.0
# Illinois               135.0  29.0
# Michigan                92.0  23.0
# Washington              75.0  23.0
# Colorado                58.0  22.0
# Texas                   49.0  22.0
# Pennsylvania           110.0  20.0
# New Jersey              56.0  19.0
# Mississippi             23.0  16.0
# Maryland                63.0  15.0
# Oregon                  36.0  13.0
# Massachusetts           50.0  11.0
# Virginia                49.0  11.0
# Alabama                 17.0   9.0
# Indiana                 50.0   9.0
# Arizona                 14.0   6.0
# Utah                    16.0   6.0
# Delaware                 8.0   4.0
# New Hampshire            8.0   4.0
# New Mexico              11.0   4.0
# Minnesota               29.0   4.0
# South Carolina          15.0   3.0
# ...

# %%
unresolved_data['Complaint_Percent']=unresolved_data['Open']/unresolved_data['Open'].sum()*100

# %%
unresolved_data[:10]
# Out:
# NewStatus     Closed  Open  Complaint_Percent
# State
# Georgia        208.0  80.0          15.473888
# California     159.0  61.0          11.798839
# Tennessee       96.0  47.0           9.090909
# Florida        201.0  39.0           7.543520
# Illinois       135.0  29.0           5.609284
# Michigan        92.0  23.0           4.448743
# Washington      75.0  23.0           4.448743
# Colorado        58.0  22.0           4.255319
# Texas           49.0  22.0           4.255319
# Pennsylvania   110.0  20.0           3.868472

# %%
Resolve_data=df.groupby(['Received Via','NewStatus']).size().unstack().fillna(0)

# %%
Resolve_data['Resolved']=Resolve_data['Closed']/Resolve_data['Closed'].sum()*100

# %%
Resolve_data['Resolved']
# Out:
# Received Via
# Customer Care Call    50.615114
# Internet              49.384886
# Name: Resolved, dtype: float64
